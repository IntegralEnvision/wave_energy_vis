# %%
import dask
import bokeh

from dask.distributed import Client
client = Client(n_workers=1, threads_per_worker=24, memory_limit='1GB')
print(client)
# Out:
# <Client: 'tcp://127.0.0.1:56050' processes=3 threads=24, memory=2.79 GiB>

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:56050' processes=3 threads=24, memory=2.79 GiB>

# %%
import dask.dataframe as dd
import datetime as dt
date = dt.datetime(2009,12,1)
spectype = 'partition'

# ftproot = 'https://polar.ncep.noaa.gov/waves/hindcasts/nopp-phase2/{}/partitions/'.format(date.strftime('%Y%m'))
outroot = '../data/{}/'.format(spectype)
grid = 'multi_reanal.partition.glo_30m'
fname = grid + '.{}'.format(date.strftime('%Y%m'))
# local_netcdf = outroot + fname + '.nc'
# url = ftproot + fname + '.nc'

ddf = dd.read_parquet(outroot + fname + '.part*.parquet')
a = ddf.hs.max()
# Out:
# -------------------------------------------------------------------------
# RuntimeError                            Traceback (most recent call last)
# C:\Users\local_aellenson\Temp\ipykernel_9684\151659058.py in <module>
#      13 ddf = dd.read_parquet(outroot + fname + '.part*.parquet')
#      14 a = ddf.hs.max()
# ---> 15 a.visualize()
#      16
#
# ~\.conda\envs\wave_energy_vis\lib\site-packages\dask\base.py in visualize(self, filename, format, optimize_graph, **kwargs)
#     239         https://docs.dask.org/en/latest/optimize.html
#     240         """
# --> 241         return visualize(
#     242             self,
#     243             filename=filename,
#
# ~\.conda\envs\wave_energy_vis\lib\site-packages\dask\base.py in visualize(filename, traverse, optimize_graph, maxval, engine, *args, **kwargs)
#     804         return cytoscape_graph(dsk, filename=filename, **kwargs)
#     805     elif engine is None:
# --> 806         raise RuntimeError(
#     807             "No visualization engine detected, please install graphviz or ipycytoscape"
#     808         )
#
# RuntimeError: No visualization engine detected, please install graphviz or ipycytoscape

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:56468' processes=1 threads=24, memory=0.93 GiB>

# %%
client.close()
